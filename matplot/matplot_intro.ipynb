# %% [markdown]
# # 📊 Introdução
#
# <strong>O que é o matplot lib?</strong>
#
# é uma biblioteca de plotagem de gráficos de baixo nível em python, para usar essa biblioteca basta instalar via pip ou em algumas plataformas igual o google colab ja vem embutido e basta apenas importar.
#
# Normalmente usamos o matplotlib com outras bibliotecas em python voltada para análise de dados.

# %%
import matplotlib

print(matplotlib.__version__) # conferindo a versão da biblioteca
# Out:
# 3.10.0

# %% [markdown]
# A maioria das coisas que utilizamos na plotagem de gráficos está dentro de um submódulo chamado pyplot, importamos ele da seguinte forma:

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# Agora, vamos criar um gráfico onde possui uma linha que inicia na posição(0,0) e vai até (6,250).

# %%
import numpy as np # outra biblioteca usada em conjunto com matplot

x = [0, 6]
y = [0,250]

plt.plot(x, y, color='#D2D0A0')
plt.show()

# %% [markdown]
# Esse foi um exemplo bem básico, existem diversos tipos de gráficos que conseguimos fazer com essa biblioteca, vamos nos aprofundar ao longo do estudo.

# %% [markdown]
# ## plot()
# essa é uma função que usamos para desenhar pontos(marcadores) em um diagrama.
# por padrão ela dsenha uma linha de ponto a ponto.<br>
# ``plt.plot(parametro_1, parametro_2)``<br>
#
# O Parâmetro 1 é uma matriz contendo os pontos do eixo x <br>
# O Parâmetro 2 é uma matriz contendo os pontos do eixo y <br>
#
# Exemplo:
#
# Desenhe uma linha em um diagrama da posição (1, 3) para a posição (8, 10):

# %%
eixo_x = [1,8]
eixo_y = [3,10]

plt.plot(eixo_x, eixo_y, color='#9EBC8A')
plt.show()

# %%
# imagine que queremos usar pontos 'o' ao invés de linhas, fazemos dessa forma:

plt.plot(eixo_x, eixo_y, 'o')
plt.show()

# %% [markdown]
# Podemos também traçar pontos múltiplos
#
# Desenhe uma linha em um diagrama da posição (1, 3) para (2, 8), depois para (6, 1) e finalmente para a posição (8, 10):

# %%
xpoints = [1,2,6,8]
ypoints = [3,8,1,10]

# Marcando os picos, ms = altera o tamanho, mec= bordas
# mfc= cores de dentro da borda
plt.plot(xpoints, ypoints, marker='o', ms=10, mec='b', mfc='green')
plt.show()

# %%
plt.plot(xpoints, ypoints, 'o:g') # Marcando os picos utilizando fmt => marker,line,color

plt.show()

# %% [markdown]
# ## Estilo de linha
# podemos usar o argumento ``linestyle ou ls`` para alterar o estilo da linha plotada.

# %%
ypoints = [1,5,9,12,16,4]

# tipos de linhas: dashed, dashdot, solid
plt.plot(ypoints, linestyle = 'dotted', marker='o', color='#9EBC8A') # definindo a cor
plt.show()

# %% [markdown]
# Para alterar a largura da linha usamos ``linewidth ou lw`` o valor vai ser um número flutuante

# %%
pontos_y = [3,8,1,10]

plt.plot(pontos_y, linewidth='12.5', color='#73946B')
plt.show()

# %% [markdown]
# <strong> Linhas múltiplas </strong>
#
# Podemos adicionar quantas linhas quisermos apenasa adicionando mais ``plt.plot()``<br>
#
# ***imagine que precisamos traçar duas linhas comparando gasto vs lucros***

# %%
import matplotlib.pyplot as plt

gastos = [44500,48000 , 45555, 25600]
lucro = [24500, 35600, 65125, 81240]
meses = ['jan', 'fev', 'mar', 'may']

plt.plot(meses, gastos , color='#73946B', linestyle='dotted')
plt.plot(meses, lucro, color='g', linestyle='solid')
plt.show()

# %% [markdown]
# Devemos sempre transmitir clareza em nossos gráficos, por isso é importante sempre está colocando títulos, legendas e etc..<br>
#
# Com matplot é possível definir também a propriedade de fonte para título e rótulos

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

# definindo as fontes
font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'darkred','size':15}

plt.plot(x, y, color='#9EBC8A')

# títulos e rótulos
plt.title('Gráfico de calorias queimas por pulso', loc='left') # Loc: define posição do texto
plt.xlabel("Pulso")
plt.ylabel("Calorias queimadas")

plt.show()

# %% [markdown]
# ### linhas de grade
# Com o Pyplot, você pode usar a ``grid()`` para adicionar linhas de grade ao gráfico.

# %%
import matplotlib.pyplot as plt

x = [80, 85, 90, 95, 100, 105, 110, 115, 120, 125]
y = [240, 250, 260, 270, 280, 290, 300, 310, 320, 330]

plt.title('Dados de esportes')
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.plot(x,y, color='#9EBC8A')

plt.grid(axis='x', color='#9EBC8A', linestyle = '--', linewidth = 0.5)
# ou axis = 'x' ou 'y' para exibir linha de grade das mesmas
# Tambem é possivel definir linestyle, linewidth = 0.5, e cor

plt.show()

# %% [markdown]
# ### subplot()
#
# com essa função conseguimos desenhar vários gráficos em uma figura.

# %%
import matplotlib.pyplot as plt

# plot 01
mes = ['jan', 'fev', 'mar']
salario = [2200, 2500, 2800]
plt.subplot(1,2,1)
plt.plot(mes,salario, color='#9EBC8A')
plt.title('2024')

# plot 02
mes = ['jan', 'fev', 'mar']
salario = [3200, 4500, 6300]
plt.subplot(1,2,2)
plt.plot(mes,salario, color='#9EBC8A')
plt.title('2025')


plt.suptitle('Lucro primeiro trimestre')
plt.show()

# %% [markdown]
# ``subplot()`` recebe três argumentos para definir o layout, que é organizado em linhas em coluna, que são representados pelo primeiro argumento

# %% [markdown]
# ### Dispersão
#
# com o pyplot usamos ``scatter()`` para desenhar um gráfico de dispersão.
# Ela precisa de duas matrizes de mesmo comprimento, uma para os valores do eixo x e outra do eixo y

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])

plt.scatter(x, y, color='#9EBC8A')
plt.show()

# %% [markdown]
# Nesse gráfico acima estamos comparando 13 carros, onde o eixo x é a idade e o Y é a velocidade, podemos observar que quanto mais novo o carro mais rápido ele corre.<br>
#
# Também conseguimos plotar dois gráficos ao mesmo tempo nessa disperção, vamos supor que agora temos dados do dia 1 e do dia 2.

# %%
import matplotlib.pyplot as plt
import numpy as np

#Dia 01
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x, y, color='#537D5D', label='Dia 01')


#Dia02
x = np.array([2,2,8,1,15,8,12,9,7,3,11,4,7,14,12])
y = np.array([100,105,84,105,90,99,90,95,94,100,79,112,91,80,85])
plt.scatter(x, y, color='#9EBC8A', label='Dia 02')

plt.title('Velocidade de carros comparado a sua idade', pad=10)
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])


plt.scatter(x, y, cmap='viridis')

plt.colorbar()

plt.show()
# Out:
# C:\Users\Daniel\AppData\Local\Temp\ipykernel_15972\1573258605.py:8: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(x, y, cmap='viridis')

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
sizes = np.array([20,50,100,200,500,1000,60,90,10,300,600,800,75])

plt.scatter(x, y, s=sizes, alpha=0.5, color='#9EBC8A')

plt.show()

# %% [markdown]
# ### Barras
# com o pyplot podemos usar ``bar()`` para desenhar gráficos de barras:
# As categorias e seus valores representados pelo primeiro e segundo argumentos como matrizes.
#
# vamos desenhar 04 barras:

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.bar(x,y, color='#73946B')
plt.show()

# %%
x = ["APPLES", "BANANAS"]

y = [400, 350]


plt.bar(x,y, width=0.4, color='#9EBC8A')
# Out:
# <BarContainer object of 2 artists>

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.barh(x,y, color='#9EBC8A')
plt.show()

# %% [markdown]
# ### Histogramas
# é um gráfico que mostra distribuições de frequências <br>
#
# usamos `hist()` para criar histogramas<br>
# Para simplificar vamos usar o Numpy para gerar aleatoriamente uma matriz com 250 valores, onde se concentrarão em torno de 170, e o desvio padrão será de 10.

# %%
import numpy as np

x = np.random.normal(170,10,250)
print(x)
# Out:
# [193.80087417 171.97222426 166.99274832 169.94249503 163.6074322
#  157.53349787 167.4077969  178.94514587 168.42970455 174.22757846
#  161.80852275 169.78323394 173.81962595 185.33665084 173.05678587
#  162.76995652 177.76472667 157.13227628 170.47914741 147.97404335
#  167.20978403 172.68117262 176.1980388  170.67076537 173.42421751
#  174.91200236 177.52467377 171.44451788 178.91894766 174.32370087
#  188.70578094 156.92017986 161.67885022 177.57179914 160.3266457
#  173.53235082 183.19602584 173.08304709 165.30254827 169.64322921
#  168.87696616 158.59338211 166.38736479 156.43283284 179.11833802
#  172.92893281 171.000561   178.40836879 173.35216121 154.81299486
#  158.92850373 157.69099775 170.97251359 171.79662101 173.9500947
#  172.71193021 176.03139878 173.07268509 179.99091964 179.33440479
#  174.96259808 172.83813708 165.55038444 153.97864612 159.51455185
#  160.18902134 165.69378082 164.66462449 171.66908651 176.09792789
# ...

# %%
plt.hist(x, color='#73946B')
plt.show()

# %% [markdown]
# ### Gráficos de pizza
# Com o pyplot, podemos usar `pie()` para desenhar gráficos de pizza:

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([35,25,25,15])
labels = ['Maçã', 'Banana', 'Amora', 'Abacaxi']
cores = ['#537D5D', '#73946B', '#9EBC8A', '#D2D0A0']
explod=[0.05, 0.0,0.0 ,0.0]

plt.figure(figsize=(10,6))
plt.pie(y, labels=labels, colors=cores, startangle=90, shadow=True, explode=explod)
plt.legend()

plt.show()
