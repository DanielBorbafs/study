# %%
import pandas as pd

df = pd.read_csv('business.csv')
df.head()
# Out:
#    matricula first_name  last_name                    email    gender  \
# 0          1     Cletis  Longhorne      clonghorne0@umn.edu      Male
# 1          2    Brigham   Deaville  bdeaville1@amazon.co.uk      Male
# 2          3     Janeva        NaN       jheinlein2@nih.gov  Bigender
# 3          4    Maynard    Stawell    mstawell3@4shared.com      Male
# 4          5    Cosette  Cullabine      ccullabine4@ted.com    Female
#
#                      profissao   salario
# 0  Administrative Assistant IV  $3167.99
# 1            Chemical Engineer  $9922.27
# 2              Staff Scientist  $2626.98
# 3          Clinical Specialist  $3211.06
# 4              Project Manager  $4864.50

# %% [markdown]
# Carregar e Visualizar os Dados
# Desafio: Carregar a base de dados em um DataFrame e exibir as primeiras e últimas 5 linhas.
# Objetivo: Entender a estrutura dos dados e verificar se há valores ausentes ou inconsistências.

# %%
ultimas_linhas = df.tail(5)
ultimas_linhas
# Out:
#      matricula first_name last_name                       email    gender  \
# 245        246   Hendrick    Heibel      hheibel6t@netscape.com      Male
# 246        247        Wat     Glenn     wglenn6u@shareasale.com      Male
# 247        248     Maudie   Ashment   mashment6v@shutterfly.com    Female
# 248        249     Darius       NaN                         NaN      Male
# 249        250       Whit   Marrows  wmarrows6x@tripadvisor.com  Bigender
#
#                        profissao    salario
# 245             Media Manager II   $9331.46
# 246              Web Designer IV  $11228.92
# 247              Sales Associate  $16818.43
# 248         Safety Technician II  $13528.86
# 249  Budget/Accounting Analyst I  $17808.75

# %%
# Localizando celulas vazias
celulas_vazias = df.isna()

# %%
# Contando quantas células vazias possuem na base
soma_celulas_vazias = celulas_vazias.sum() # Por coluna
print(soma_celulas_vazias)

total_soma_celulas_vazias = soma_celulas_vazias.sum()
print(f'Possuimos um total de {total_soma_celulas_vazias} células vazias')
# Out:
# matricula      0
# first_name     0
# last_name     19
# email         22
# gender         0
# profissao      0
# salario        0
# dtype: int64
# Possuimos um total de 41 células vazias

# %%
# Subistituindo células vazias
df.fillna('não informado', inplace=True)

df
# Out:
#      matricula first_name      last_name                       email  \
# 0            1     Cletis      Longhorne         clonghorne0@umn.edu
# 1            2    Brigham       Deaville     bdeaville1@amazon.co.uk
# 2            3     Janeva  não informado          jheinlein2@nih.gov
# 3            4    Maynard        Stawell       mstawell3@4shared.com
# 4            5    Cosette      Cullabine         ccullabine4@ted.com
# ..         ...        ...            ...                         ...
# 245        246   Hendrick         Heibel      hheibel6t@netscape.com
# 246        247        Wat          Glenn     wglenn6u@shareasale.com
# 247        248     Maudie        Ashment   mashment6v@shutterfly.com
# 248        249     Darius  não informado               não informado
# 249        250       Whit        Marrows  wmarrows6x@tripadvisor.com
#
#        gender                    profissao    salario
# 0        Male  Administrative Assistant IV   $3167.99
# 1        Male            Chemical Engineer   $9922.27
# 2    Bigender              Staff Scientist   $2626.98
# 3        Male          Clinical Specialist   $3211.06
# 4      Female              Project Manager   $4864.50
# ..        ...                          ...        ...
# 245      Male             Media Manager II   $9331.46
# 246      Male              Web Designer IV  $11228.92
# 247    Female              Sales Associate  $16818.43
# 248      Male         Safety Technician II  $13528.86
# 249  Bigender  Budget/Accounting Analyst I  $17808.75
#
# [250 rows x 7 columns]

# %% [markdown]
# Desafio: Gerar um resumo estatístico dos salários.
#
# Objetivo: Obter informações como média, mediana, desvio padrão, valores máximos e mínimos, etc., para analisar a distribuição dos salários e idades.

# %%
# Como se trata de valor monetario precisamos remover o $ para podermos trabalhar com estatística
import pandas as pd

df = pd.read_csv('business.csv')

df['salario'] = df['salario'].replace({'\$': '', ',': ''}, regex=True).astype(float)
# Out:
# <>:6: SyntaxWarning: invalid escape sequence '\$'
# <>:6: SyntaxWarning: invalid escape sequence '\$'
# C:\Users\Daniel\AppData\Local\Temp\ipykernel_14264\600301918.py:6: SyntaxWarning: invalid escape sequence '\$'
#   df['salario'] = df['salario'].replace({'\$': '', ',': ''}, regex=True).astype(float)

# %%
# Gerando um resumo estatístico geral
resumo_Salarial = df['salario'].describe()
print(resumo_Salarial.count)
# Out:
# <bound method Series.count of count      250.000000
# mean     10353.058360
# std       5059.435079
# min       1445.240000
# 25%       6121.485000
# 50%      10384.820000
# 75%      14770.210000
# max      19149.240000
# Name: salario, dtype: float64>

# %% [markdown]
# Vamos verificar quantas pessoas exercem cada cargo

# %%
conta_duplicados = df['profissao'].value_counts()
print(conta_duplicados.to_string())
# Out:
# profissao
# Graphic Designer                  5
# Chief Design Engineer             5
# Marketing Manager                 5
# Sales Associate                   5
# Assistant Professor               5
# Chemical Engineer                 4
# Junior Executive                  4
# Staff Scientist                   4
# Teacher                           4
# Registered Nurse                  4
# Structural Analysis Engineer      4
# Senior Quality Engineer           4
# Software Test Engineer III        4
# Quality Control Specialist        4
# Project Manager                   3
# Clinical Specialist               3
# Sales Representative              3
# VP Product Management             3
# Cost Accountant                   3
# Administrative Officer            3
# Help Desk Operator                3
# Professor                         3
# Food Chemist                      3
# Desktop Support Technician        3
# Research Associate                3
# Assistant Manager                 3
# Research Nurse                    3
# Recruiter                         3
# Payment Adjustment Coordinator    3
# Human Resources Manager           3
# Statistician III                  3
# Paralegal                         3
# Compensation Analyst              3
# Help Desk Technician              3
# Internal Auditor                  2
# Social Worker                     2
# Accountant I                      2
# Dental Hygienist                  2
# Account Executive                 2
# Senior Sales Associate            2
# Software Consultant               2
# Media Manager II                  2
# Quality Engineer                  2
# Safety Technician IV              2
# VP Sales                          2
# Engineer III                      2
# Database Administrator IV         2
# Staff Accountant II               2
# Senior Financial Analyst          2
# Human Resources Assistant II      2
# Programmer II                     2
# Community Outreach Specialist     2
# VP Quality Control                2
# Safety Technician II              2
# Technical Writer                  2
# VP Accounting                     2
# Design Engineer                   2
# Editor                            2
# Senior Editor                     2
# Data Coordinator                  2
# Human Resources Assistant I       2
# Administrative Assistant IV       1
# Recruiting Manager                1
# Software Engineer IV              1
# Mechanical Systems Engineer       1
# Accountant II                     1
# Assistant Media Planner           1
# Health Coach I                    1
# Occupational Therapist            1
# Programmer Analyst III            1
# Marketing Assistant               1
# Research Assistant IV             1
# Office Assistant II               1
# Budget/Accounting Analyst III     1
# Accounting Assistant III          1
# Health Coach II                   1
# Product Engineer                  1
# Safety Technician I               1
# Office Assistant IV               1
# Programmer Analyst I              1
# Senior Developer                  1
# Structural Engineer               1
# Administrative Assistant I        1
# Statistician IV                   1
# Nuclear Power Engineer            1
# Engineer I                        1
# Database Administrator III        1
# Web Developer III                 1
# Analog Circuit Design manager     1
# Nurse                             1
# Physical Therapy Assistant        1
# Web Developer IV                  1
# Civil Engineer                    1
# Engineer IV                       1
# Accounting Assistant I            1
# Programmer Analyst IV             1
# General Manager                   1
# Statistician I                    1
# Financial Advisor                 1
# Web Designer II                   1
# Actuary                           1
# Statistician II                   1
# Business Systems Analyst          1
# Geological Engineer               1
# Accountant IV                     1
# Executive Secretary               1
# Pharmacist                        1
# Director of Sales                 1
# Health Coach III                  1
# Biostatistician IV                1
# Information Systems Manager       1
# Account Representative II         1
# Computer Systems Analyst II       1
# Administrative Assistant II       1
# Automation Specialist IV          1
# Media Manager IV                  1
# Operator                          1
# Biostatistician III               1
# GIS Technical Architect           1
# Account Coordinator               1
# Budget/Accounting Analyst IV      1
# Tax Accountant                    1
# Senior Cost Accountant            1
# Environmental Tech                1
# Developer II                      1
# Media Manager III                 1
# Computer Systems Analyst III      1
# Accountant III                    1
# Account Representative IV         1
# Legal Assistant                   1
# Web Developer II                  1
# Nurse Practicioner                1
# Financial Analyst                 1
# Programmer I                      1
# Web Designer IV                   1
# Budget/Accounting Analyst I       1

# %% [markdown]
# Distribuição de Salários por Departamento
#
# Desafio: Calcular a média, o valor máximo e o valor mínimo dos salários por departamento.
#
# Objetivo: Verificar quais departamentos estão pagando mais ou menos em média e encontrar possíveis discrepâncias salariais entre departamentos.

# %%
# Filtrando por um departamento especifico
df_sales = df[df['profissao'] == 'Sales Associate']
media_df_sales = round(df_sales['salario'].mean(),2)
mediana_df_sales = round(df_sales['salario'].median(),2)
mode_df_sales = round(df_sales['salario'].mode())
media_df_sales, mediana_df_sales # 13506.72  17473.02   4535. 55
# Out:
# (np.float64(13506.72), np.float64(15160.05))

# %%
# Filtrando por todos departamentos

salarios_por_departamento = df.groupby('profissao')['salario'].agg(
    media = 'mean',
    maximo = 'max',
    minimo = 'min'
).round(2)

# Ordenando por departamentos que possui uma media maior
salarios_por_departamento = salarios_por_departamento.sort_values(by='maximo', ascending=False)

print(salarios_por_departamento.to_string())
# Out:
#                                    media    maximo    minimo
# profissao
# Accounting Assistant I          19149.24  19149.24  19149.24
# Human Resources Assistant I     10920.94  19045.89   2795.98
# Research Associate              13498.70  19021.27   4290.39
# Office Assistant II             18834.61  18834.61  18834.61
# Business Systems Analyst        18637.46  18637.46  18637.46
# Engineer III                    12520.24  18616.13   6424.34
# Safety Technician II            16033.32  18537.79  13528.86
# Executive Secretary             18507.15  18507.15  18507.15
# Media Manager IV                18408.86  18408.86  18408.86
# Compensation Analyst            14825.29  18389.65   8421.12
# Automation Specialist IV        18350.39  18350.39  18350.39
# Clinical Specialist             10640.31  18310.71   3211.06
# Health Coach III                18278.57  18278.57  18278.57
# Senior Financial Analyst        15554.68  18110.57  12998.79
# Analog Circuit Design manager   17915.15  17915.15  17915.15
# Budget/Accounting Analyst I     17808.75  17808.75  17808.75
# Graphic Designer                10637.66  17586.04   2499.22
# Assistant Professor             14065.36  17568.62  10699.96
# Paralegal                       12755.89  17567.25   3766.98
# Safety Technician IV            16170.30  17504.06  14836.55
# Sales Associate                 13506.72  17473.02   4535.55
# Community Outreach Specialist    6480.60  10225.07   2736.14
# Safety Technician I             10223.54  10223.54  10223.54
# Web Designer II                  9797.41   9797.41   9797.41
# VP Sales                         7119.74   9567.71   4671.78
# Accountant III                   9449.25   9449.25   9449.25
# Media Manager II                 5388.35   9331.46   1445.24
# Information Systems Manager      9313.44   9313.44   9313.44
# General Manager                  9240.05   9240.05   9240.05
# Software Consultant              8901.48   9041.08   8761.89
# Financial Advisor                8967.15   8967.15   8967.15
# Web Developer II                 8949.58   8949.58   8949.58
# Structural Engineer              8785.96   8785.96   8785.96
# Payment Adjustment Coordinator   6619.37   8585.05   4393.39
# Operator                         8503.65   8503.65   8503.65
# Accountant IV                    8418.69   8418.69   8418.69
# Legal Assistant                  8297.69   8297.69   8297.69
# Design Engineer                  5551.46   8272.49   2830.43
# Account Representative IV        8228.84   8228.84   8228.84
# Health Coach II                  7807.98   7807.98   7807.98
# Accountant I                     6572.26   7652.22   5492.30
# Budget/Accounting Analyst III    7586.18   7586.18   7586.18
# GIS Technical Architect          7457.63   7457.63   7457.63
# Environmental Tech               7339.83   7339.83   7339.83
# Database Administrator III       7306.10   7306.10   7306.10
# Marketing Assistant              7243.66   7243.66   7243.66
# Assistant Media Planner          6868.28   6868.28   6868.28
# Programmer I                     6830.21   6830.21   6830.21
# Senior Developer                 6741.62   6741.62   6741.62
# Civil Engineer                   5550.63   5550.63   5550.63
# Dental Hygienist                 4331.03   5399.69   3262.37
# Financial Analyst                5395.18   5395.18   5395.18
# Statistician I                   5241.43   5241.43   5241.43
# Nurse Practicioner               4704.51   4704.51   4704.51
# Programmer II                    3997.46   4471.14   3523.77
# Staff Accountant II              3790.72   4416.39   3165.05
# Engineer IV                      4266.69   4266.69   4266.69
# Web Developer IV                 4224.15   4224.15   4224.15
# Structural Analysis Engineer     2777.36   4061.56   1863.85
# Accountant II                    3931.96   3931.96   3931.96
# Tax Accountant                   3428.40   3428.40   3428.40
# Programmer Analyst I             3366.69   3366.69   3366.69
# Statistician IV                  3248.24   3248.24   3248.24
# Computer Systems Analyst II      3204.65   3204.65   3204.65
# Administrative Assistant IV      3167.99   3167.99   3167.99
# Software Engineer IV             3118.31   3118.31   3118.31
# Research Assistant IV            2939.30   2939.30   2939.30
# Biostatistician IV               2801.86   2801.86   2801.86
# Budget/Accounting Analyst IV     2040.75   2040.75   2040.75
# Recruiting Manager               2038.72   2038.72   2038.72
# Administrative Assistant II      1515.05   1515.05   1515.05

# %%
df['email'] = df['email'].fillna('nao informado')
df['last_name'] = df['last_name'].fillna('nao informado')

# %% [markdown]
# Desafio: Filtrar os funcionários que ganham acima de um valor específico (por exemplo, R$10.000).
#
# Objetivo: Identificar os funcionários que recebem salários mais altos e explorar suas características.

# %%
# buscando salarios acima de 10.0000
salarios_maiores = df[df['salario'] > 10000]

print(salarios_maiores.to_string())
# Out:
#      matricula  first_name       last_name                             email       gender                      profissao   salario
# 6            7       Lenee         Peracco                 lperacco6@ask.com       Female                  Social Worker  17102.76
# 7            8       Blair           Esome               besome7@behance.net       Female         Administrative Officer  15199.50
# 199        200         Wes        Gatcliff         wgatcliff5j@rakuten.co.jp         Male               Statistician III  13052.41
# 201        202      Derrik       Blowfelde        dblowfelde5l@cafepress.com         Male      Database Administrator IV  10971.38
# 203        204    Beverlie          Bryant                     nao informado       Female       Senior Financial Analyst  18110.57
# 204        205      Halley           Akast                  hakast5o@dot.gov       Female                   Food Chemist  14562.55
# 206        207        Alfy          Graver  agraver5q@scientificamerican.com       Female                   Engineer III  18616.13
# 207        208      Sibbie         Ranking           sranking5r@sakura.ne.jp       Female           Safety Technician II  18537.79
# 208        209     Raimund          Cayton                rcayton5s@usgs.gov         Male         Senior Cost Accountant  10381.73
# 210        211     Donella          Pachta                dpachta5u@1und1.de       Female                      Recruiter  14975.82
# 212        213       Nerta   nao informado                  nudie5w@java.com       Female            Clinical Specialist  10399.16
# 213        214      Paloma        Tredwell            ptredwell5x@census.gov       Female              Marketing Manager  11454.93
# 214        215         Fan      California          fcalifornia5y@hao123.com       Female                   Developer II  15555.56
# 216        217    Guillema         Girling              ggirling60@amazon.de       Female                      Paralegal  17567.25
# 218        219     Othelia     Constantine          oconstantine62@naver.com  Genderqueer               Graphic Designer  17586.04
# 219        220      Vaughn          Malley               vmalley63@desdev.cn   Polygender             Research Associate  17184.43
# 221        222      Alexis       Hackleton        ahackleton65@123-reg.co.uk         Male              Media Manager III  10856.22
# 224        225       Nedda        McMurthy                     nao informado       Female           Help Desk Technician  16033.95
# 225        226         Lee            Room         lroom69@howstuffworks.com       Female                Project Manager  11169.61
# 226        227       Dario        Pethrick             dpethrick6a@hc360.com         Male               Junior Executive  12305.38
# 227        228     Kirstyn         Eastway              keastway6b@phpbb.com       Female               Technical Writer  10090.02
# 228        229        Farr          Zanini               fzanini6c@wufoo.com         Male    Human Resources Assistant I  19045.89
# 230        231      Eudora           Enden                  eenden6e@last.fm       Female           Sales Representative  15148.68
# 231        232      Ariana   nao informado               ajurkiewicz6f@de.vu  Genderfluid   Computer Systems Analyst III  15066.31
# 234        235      Frazer          Leggan             fleggan6i@behance.net         Male             VP Quality Control  11833.11
# 236        237   Benedikta          Mithon                     nao informado       Female           Safety Technician IV  17504.06
# 238        239     Stephen          Rosone                srosone6m@nasa.gov         Male           Compensation Analyst  17665.11
# 246        247         Wat           Glenn           wglenn6u@shareasale.com         Male                Web Designer IV  11228.92
# 247        248      Maudie         Ashment         mashment6v@shutterfly.com       Female                Sales Associate  16818.43
# 248        249      Darius   nao informado                     nao informado         Male           Safety Technician II  13528.86
# 249        250        Whit         Marrows        wmarrows6x@tripadvisor.com     Bigender    Budget/Accounting Analyst I  17808.75

# %% [markdown]
# Análise de Gênero e Salário
#
# Desafio: Comparar a média de salários entre homens e mulheres.
#
# Objetivo: Avaliar se existe uma disparidade salarial entre os gêneros.

# %%
salarios_por_genero = df.groupby('gender')['salario'].agg(
    media = 'mean',
    maximo = 'max',
    minimo = 'min'
).round(2)

salarios_por_genero = salarios_por_genero.sort_values(by='media', ascending=False)
salarios_por_genero
# Out:
#                 media    maximo   minimo
# gender
# Non-binary   14221.94  18637.46  8585.05
# Genderqueer  12437.05  18389.65  4266.69
# Bigender     12151.33  17808.75  2626.98
# Genderfluid  10860.33  15066.31  3931.96
# Male         10296.55  19149.24  1654.55
# Female       10184.91  18834.61  1515.05
# Polygender    8950.55  17184.43  1445.24
# Agender       5849.86   5849.86  5849.86

# %%
# Filtrando por um gênero específico, por exemplo: male
filtro_salarios = salarios_por_genero.loc['Agender']
print(filtro_salarios)
# Out:
# media     5849.86
# maximo    5849.86
# minimo    5849.86
# Name: Agender, dtype: float64

# %% [markdown]
# Criando uma função que traz as estatísticas dos salários de forma aleatória

# %%
import random

# Transformando a coluna sexo em uma tupla
listGeneros = tuple(df['gender'].unique())

def filtro_por_genero_aleatorio(salarios_por_genero, generos):
    genero_aleatorio = random.choice(generos)
    filtro_salarios = salarios_por_genero.loc[genero_aleatorio]
    return genero_aleatorio, filtro_salarios

genero, filtro_salarios = filtro_por_genero_aleatorio(salarios_por_genero, listGeneros)

print(f'Gênero selecionado: {genero}')
print(f'Dados do gênero selecionado: \n{filtro_salarios}')
# Out:
# Gênero selecionado: Non-binary
# Dados do gênero selecionado:
# media     14221.94
# maximo    18637.46
# minimo     8585.05
# Name: Non-binary, dtype: float64

# %% [markdown]
# Top 5 Funcionários com Maiores Salários
#
# Desafio: Encontrar os 5 funcionários com os maiores salários.
#
# Objetivo: Identificar quem são os top 5 funcionários mais bem pagos e analisar suas características.

# %%
top_salarios = df.nlargest(5, 'salario')[['first_name', 'salario']]
top_salarios
# Out:
#     first_name   salario
# 119      Romeo  19149.24
# 228       Farr  19045.89
# 171     Lamond  19021.27
# 93      Kellie  18834.61
# 99       Paige  18637.46

# %% [markdown]
# Instalando o matplotlib para visualizar alguns dados importantes

# %%
! pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\daniel\appdata\local\programs\python\python313\lib\site-packages (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\daniel\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\daniel\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\daniel\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\daniel\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: numpy>=1.23 in c:\users\daniel\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (2.2.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\daniel\appdata\roaming\python\python313\site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\daniel\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\daniel\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\daniel\appdata\roaming\python\python313\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\daniel\appdata\roaming\python\python313\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)

# %%
import matplotlib.pyplot as plt

media_salarial_genero = df.groupby('gender')['salario'].mean()

# criando gráficos de barras
plt.figure(figsize=(10, 6))
media_salarial_genero.plot(kind='bar', color='skyblue')

#adicionando títulos

plt.title('Média salarial por gênero', fontsize=16)
plt.xlabel('Gênero', fontsize=14)
plt.ylabel('Média Salarial', fontsize=14)

plt.xticks(rotation = 0) # colando nomes na horizontal

for i, v in enumerate(media_salarial_genero):
    plt.text(i, v + 100, f'R$ {v:.2f}', ha='center', va='bottom', fontsize=10)  # Ajuste do valor acima da barra

plt.tight_layout()
plt.show()

# %% [markdown]
# Agora vamos trazer uma média salarial por cargo, nessa base de dados possuí muitos cargos então um gráfico com todos os cargos fica impossível de ler, vamos filtrar pelos top 10 caargos.

# %%
import matplotlib.pyplot as plt

# Calcular a média salarial por profissão
media_salarial_cargo = df.groupby('profissao')['salario'].mean()

# Selecionar os 8 cargos com maiores salários
top_10_salarios = media_salarial_cargo.sort_values(ascending=False).head(10)

# Criando gráfico de barras horizontais
plt.figure(figsize=(14, 6))
top_10_salarios.plot(kind='barh', color='skyblue')

# Adicionando títulos
plt.title('Top 10 cargos com maiores médias salariais')
plt.xlabel('Média Salarial', fontsize=16)
plt.ylabel('Cargo', fontsize=14)

# Adicionando os valores nas barras
for i, v in enumerate(top_10_salarios):
    plt.text(v + 100, i, f'R$ {v:.2f}', ha='left', va='center', fontsize=6)




plt.tight_layout()
plt.show()
